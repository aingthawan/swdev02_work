# %%
sw = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "entirely", "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "ey", "f", "f2", "fa", "far", "fc", "few", "ff", "fi", "fifteen", "fifth", "fify", "fill", "find", "fire", "first", "five", "fix", "fj", "fl", "fn", "fo", "followed", "following", "follows", "for", "former", "formerly", "forth", "forty", "found", "four", "fr", "from", "front", "fs", "ft", "fu", "full", "further", "furthermore", "fy", "g", "ga", "gave", "ge", "get", "gets", "getting", "gi", "give", "given", "gives", "giving", "gj", "gl", "go", "goes", "going", "gone", "got", "gotten", "gr", "greetings", "gs", "gy", "h", "h2", "h3", "had", "hadn", "hadn't", "happens", "hardly", "has", "hasn", "hasnt", "hasn't", "have", "haven", "haven't", "having", "he", "hed", "he'd", "he'll", "hello", "help", "hence",
import requests
from bs4 import BeautifulSoup

# %%
def open_html_35mmc(url):
    web_data = requests.get(url)
    soup = BeautifulSoup(web_data.text, "html.parser")
    return soup.find("article").text

def open_html_pantip(url):
    web_data = requests.get(url)
    soup = BeautifulSoup(web_data.text, "html.parser")
#     print(soup.find("div", {'class':'container-inner'}).text)
    return soup.find("div", {'class':'container-inner'}).text

# %%
def get_kw(pure_text):
#     stopwords = ["a", "and", "the", "in", "on", "at"]
    stopwords = sw

    ext_keywords = yake.KeywordExtractor(lan="en", stopwords=stopwords)
    keywords = ext_keywords.extract_keywords(pure_text)
    for kw, v in keywords:
        print("Keyphrase: ", kw, ": score", v)

# %%
# with Yake
url = "https://www.35mmc.com/28/09/2021/leica-iif-red-dial-nostalgia-or-tool-for-serious-storytelling-by-exphotog/"
pure_text = open_html_35mmc(url)
get_kw(pure_text)
# Out:
# Keyphrase:  Leica IIf Red : score 0.015755575699084146
# Keyphrase:  Leica : score 0.01947913939712152
# Keyphrase:  Leica IIf : score 0.024032959687317872
# Keyphrase:  IIf : score 0.028532415182906133
# Keyphrase:  Changeable Lens : score 0.03147932419298211
# Keyphrase:  film : score 0.03327072941827255
# Keyphrase:  IIf Red Dial : score 0.03344395786617747
# Keyphrase:  camera : score 0.03443089474000568
# Keyphrase:  photography : score 0.03973844439433435
# Keyphrase:  Leica iiif leica : score 0.042784444201949344
# Keyphrase:  n’t : score 0.05360549210017556
# Keyphrase:  work : score 0.064665492798181
# Keyphrase:  Changeable : score 0.06533059186940829
# Keyphrase:  IIf Red : score 0.06549065694683291
# Keyphrase:  Concert photography : score 0.06781165340375588
# Keyphrase:  cameras : score 0.07746951316501277
# Keyphrase:  Red Dial : score 0.08787498445175193
# Keyphrase:  experience : score 0.09253325839705669
# Keyphrase:  concert : score 0.09391591447363726
# Keyphrase:  slow film : score 0.1059741833144884

# %%
# with KeyBert
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(pure_text, keyphrase_ngram_range=(1, 2))
print(keywords)
# Out:
# [('concert photography', 0.7061), ('stage photography', 0.5701), ('concert photographer', 0.5578), ('working concert', 0.5375), ('concert', 0.5226)]

# %%
# with Rake
from rake_nltk import Rake
r = Rake()
r.extract_keywords_from_text(pure_text)
r.get_ranked_phrases_with_scores()
# Out:
# [(33.5, 'vintage glass creates pleasant images even'),
#  (27.863636363636363,
#   'leica iiif leica rangefinder rangefinder cameracontribute'),
#  (21.6, 'even slower film loading mechanism'),
#  (20.75, 'lens combination working especially well'),
#  (19.85, 'film began many years prior'),
#  (18.0, '“ feel ” thing –'),
#  (16.916666666666668, 'separate slow shutter speed dial'),
#  (16.8015873015873, 'window — taming one ’'),
#  (16.0, 'witness bands complete soundcheck'),
#  (16.0, 'particularly cold july morning'),
#  (15.6, 'slow film advance mechanism'),
#  (15.5, '“ first three songs'),
#  (15.5, 'undoubtedly handsome collapsible 50mm'),
#  (15.333333333333334, 'perceived cons really affected'),
#  (14.75, 'ebay many years ago'),
#  (14.1, 'slow film advance knob'),
#  (14.0, 'vividly remember snapping photos'),
#  (13.875, 'alternative photography community blog'),
#  (13.833333333333334, 'definitely recommend zone focusing'),
#  (13.626262626262626, 'leica iiifleica rangefinderrangefinder camera'),
#  (13.606060606060606, 'leica iif red dial'),
#  (13.606060606060606, 'leica iif red dial'),
#  (13.6, 'revolve around auto focus'),
#  (10.333333333333334, 'slow shutter speeds'),
#  (10.0, 'many fine scratches'),
#  (9.25, 'collapsible lens makes'),
#  (9.0, 'vibrant neighborhood near'),
#  (9.0, 'took six weeks'),
#  (9.0, 'significant coating wear'),
#  (9.0, 'shooting 900 frames'),
#  (9.0, 'scan adjustments done'),
#  (9.0, 'primordial performing live'),
#  (9.0, 'lubitel lomo 166b'),
#  (9.0, 'following tag links'),
#  (9.0, 'entire kit pocketable'),
#  (9.0, 'elmar 5cm f'),
#  (9.0, 'barnack leicas offered'),
#  (9.0, 'also weighs less'),
#  (9.0, 'also flipped inside'),
#  (9.0, '99 per month'),
#  (8.944444444444445, 'camera definitely grew'),
#  (8.833333333333334, 'never really expected'),
#  (8.681818181818182, 'leica ms ),'),
#  (8.544444444444444, 'first film camera'),
#  (8.5, 'clickless aperture ring'),
#  (8.444444444444445, 'please click one'),
#  (8.444444444444445, 'everything one knows'),
#  (8.4, 'surprisingly satisfying experience'),
#  (8.4, 'photo pit experience'),
#  (8.333333333333334, 'subject matter discussed'),
#  (8.333333333333334, 'really feel limited'),
#  (8.09090909090909, 'iif would perform'),
#  (8.044444444444444, 'one jostles around'),
#  (8.0, 'summitar 5cm f'),
#  (8.0, 'mostly overcast day'),
#  (8.0, 'external light meter'),
#  (8.0, 'exphotog september 28'),
#  (8.0, 'black photo pit'),
#  (7.944444444444445, 'local camera store'),
#  (7.833333333333334, 'dramatic subject matter'),
#  (7.8, 'time last year'),
#  (7.75, 'inherently laborious nature'),
#  (7.666666666666667, 'documentary type work'),
#  (7.066666666666666, 'experience 35mmc without'),
#  (7.05, 'time favorite cameras'),
#  (6.85, 'shoot cameras around'),
#  (6.757575757575758, 'iif pure nostalgia'),
#  (6.666666666666667, 'pit much like'),
#  (6.6, 'loading film'),
#  (6.0, 'vintage feel'),
#  (6.0, 'separate focus'),
#  (5.583333333333334, 'shutter speed'),
#  (5.5, 'flash ”'),
#  (5.2727272727272725, 'leica iif'),
#  (5.1, 'processing film'),
#  (5.1, 'film exclusively'),
#  (5.1, 'develop film'),
#  (5.1, 'biggest film'),
#  (5.0, 'separate viewfinders'),
#  (5.0, 'negatives —'),
#  (5.0, 'knob vs'),
#  (5.0, 'first impressions'),
#  (4.931818181818182, 'leica world'),
#  (4.75, 'changeable lens'),
#  (4.681818181818182, 'leica m2'),
#  (4.6, 'wait around'),
#  (4.5, 'rolleiflex ),'),
#  (4.5, 'mostly clad'),
#  (4.5, 'local lab'),
#  (4.5, 'easy —'),
#  (4.5, 'dramatic effect'),
#  (4.5, 'day trial'),
#  (4.5, 'aperture values'),
#  (4.444444444444445, 'requires one'),
#  (4.444444444444445, 'one needs'),
#  (4.444444444444445, 'gorgeous camera'),
#  (4.444444444444445, 'fun camera'),
#  (2.75, 'lens'),
#  (2.6, 'around'),
#  (2.4444444444444446, 'one'),
#  (2.4444444444444446, 'one'),
#  (2.4444444444444446, 'camera'),
#  (2.4, 'experience'),
#  (2.3333333333333335, 'matter'),
#  (2.3333333333333335, 'focusing'),
#  (2.25, 'speed'),
#  (2.25, 'speed'),
#  (2.25, 'cameras'),
#  (2.090909090909091, 'iif'),
#  (2.090909090909091, 'iif'),
#  (2.090909090909091, 'iif'),
#  (2.090909090909091, 'iif'),
#  (2.090909090909091, 'iif'),
#  (2.0, 'summitar'),
#  (2.0, 'shoot'),
#  (2.0, 'photos'),
#  (2.0, 'photos'),
#  (2.0, 'like'),
#  (2.0, 'light'),
#  (2.0, 'feel'),
#  (2.0, 'feel'),
#  (2.0, 'feel'),
#  (2.0, 'feel'),
#  (2.0, 'exphotog'),
#  (2.0, 'black'),
#  (1.875, 'photography'),
#  (1.875, 'photography'),
#  (1.875, 'photography'),
#  (1.8, 'time'),
#  (1.8, 'time'),
#  (1.8, 'time'),
#  (1.8, ').'),
#  (1.75, 'world'),
#  (1.75, 'nature'),
#  (1.75, 'nature'),
#  (1.6666666666666667, 'work'),
#  (1.6666666666666667, 'work'),
#  (1.6666666666666667, 'work'),
#  (1.6666666666666667, 'nostalgia'),
#  (1.6666666666666667, 'nostalgia'),
#  (1.6666666666666667, 'much'),
#  (1.6666666666666667, 'much'),
#  (1.6666666666666667, 'lot'),
#  (1.6666666666666667, 'finally'),
#  (1.6666666666666667, '35mmc'),
#  (1.6666666666666667, '35mmc'),
#  (1.5, 'two'),
#  (1.5, 'things'),
#  (1.5, 'take'),
#  (1.5, 'setting'),
#  (1.5, 'promised'),
#  (1.5, 'photographer'),
#  (1.5, 'm2'),
#  (1.5, 'important'),
#  (1.5, 'goes'),
#  (1.5, 'full'),
#  (1.5, 'explore'),
#  (1.5, 'easy'),
#  (1.5, 'composition'),
#  (1.5, '3'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3571428571428572, '’'),
#  (1.3333333333333333, 'tool'),
#  (1.3333333333333333, 'tool'),
#  (1.25, 'see'),
#  (1.25, 'see'),
#  (1.25, 'see'),
#  (1.25, 'decided'),
#  (1.25, 'decided'),
#  (1.25, 'decided'),
#  (1.0, 'wrestling'),
#  (1.0, 'weather'),
#  (1.0, 'wanted'),
#  (1.0, 'video'),
#  (1.0, 'venue'),
#  (1.0, 'value'),
#  (1.0, 'ushered'),
#  (1.0, 'use'),
#  (1.0, 'use'),
#  (1.0, 'use'),
#  (1.0, 'universe'),
#  (1.0, 'uneasy'),
#  (1.0, 'turn'),
#  (1.0, 'try'),
#  (1.0, 'truth'),
#  (1.0, 'transition'),
#  (1.0, 'tradeoffs'),
#  (1.0, 'timers'),
#  (1.0, 'tight'),
#  (1.0, 'though'),
#  (1.0, 'theory'),
#  (1.0, 'tension'),
#  (1.0, 'taught'),
#  (1.0, 'switch'),
#  (1.0, 'sweating'),
#  (1.0, 'subscribe'),
#  (1.0, 'streets'),
#  (1.0, 'starters'),
#  (1.0, 'stage'),
#  (1.0, 'size'),
#  (1.0, 'sign'),
#  (1.0, 'shot'),
#  (1.0, 'shot'),
#  (1.0, 'share'),
#  (1.0, 'set'),
#  (1.0, 'security'),
#  (1.0, 'second'),
#  (1.0, 'scene'),
#  (1.0, 'say'),
#  (1.0, 'saw'),
#  (1.0, 'safety'),
#  (1.0, 'rotation'),
#  (1.0, 'roll'),
#  (1.0, 'right'),
#  (1.0, 'research'),
#  (1.0, 'reimagine'),
#  (1.0, 'reconcile'),
#  (1.0, 'recently'),
#  (1.0, 'rangefinders'),
#  (1.0, 'questions'),
#  (1.0, 'purchased'),
#  (1.0, 'purchased'),
#  (1.0, 'profile'),
#  (1.0, 'processed'),
#  (1.0, 'posts'),
#  (1.0, 'place'),
#  (1.0, 'pitch'),
#  (1.0, 'people'),
#  (1.0, 'patience'),
#  (1.0, 'patience'),
#  (1.0, 'part'),
#  (1.0, 'owned'),
#  (1.0, 'order'),
#  (1.0, 'nowadays'),
#  (1.0, 'norway'),
#  (1.0, 'none'),
#  (1.0, 'need'),
#  (1.0, 'move'),
#  (1.0, 'money'),
#  (1.0, 'metering'),
#  (1.0, 'luckily'),
#  (1.0, 'love'),
#  (1.0, 'looks'),
#  (1.0, 'loaded'),
#  (1.0, 'life'),
#  (1.0, 'life'),
#  (1.0, 'lever'),
#  (1.0, 'lack'),
#  (1.0, 'keepers'),
#  (1.0, 'joy'),
#  (1.0, 'journey'),
#  (1.0, 'instilled'),
#  (1.0, 'importantly'),
#  (1.0, 'importantly'),
#  (1.0, 'importantly'),
#  (1.0, 'house'),
#  (1.0, 'hours'),
#  (1.0, 'headbanging'),
#  (1.0, 'handling'),
#  (1.0, 'good'),
#  (1.0, 'good'),
#  (1.0, 'gone'),
#  (1.0, 'give'),
#  (1.0, 'give'),
#  (1.0, 'get'),
#  (1.0, 'get'),
#  (1.0, 'gear'),
#  (1.0, 'fuss'),
#  (1.0, 'flow'),
#  (1.0, 'flaws'),
#  (1.0, 'field'),
#  (1.0, 'far'),
#  (1.0, 'factors'),
#  (1.0, 'eyes'),
#  (1.0, 'experiences'),
#  (1.0, 'exhilarating'),
#  (1.0, 'excellent'),
#  (1.0, 'enjoy'),
#  (1.0, 'emotions'),
#  (1.0, 'embrace'),
#  (1.0, 'elements'),
#  (1.0, 'easily'),
#  (1.0, 'drew'),
#  (1.0, 'development'),
#  (1.0, 'despite'),
#  (1.0, 'despite'),
#  (1.0, 'descend'),
#  (1.0, 'decision'),
#  (1.0, 'deal'),
#  (1.0, 'darkness'),
#  (1.0, 'cut'),
#  (1.0, 'cumbersome'),
#  (1.0, 'core'),
#  (1.0, 'copy'),
#  (1.0, 'contributors'),
#  (1.0, 'compensated'),
#  (1.0, 'compact'),
#  (1.0, 'comfort'),
#  (1.0, 'child'),
#  (1.0, 'case'),
#  (1.0, 'carry'),
#  (1.0, 'buy'),
#  (1.0, 'buck'),
#  (1.0, 'bought'),
#  (1.0, 'bond'),
#  (1.0, 'bodies'),
#  (1.0, 'become'),
#  (1.0, 'based'),
#  (1.0, 'aware'),
#  (1.0, 'astonishing'),
#  (1.0, 'articles'),
#  (1.0, 'arrive'),
#  (1.0, 'approach'),
#  (1.0, 'anticipate'),
#  (1.0, 'answer'),
#  (1.0, 'among'),
#  (1.0, 'although'),
#  (1.0, 'along'),
#  (1.0, 'along'),
#  (1.0, 'alcohol'),
#  (1.0, 'adverts'),
#  (1.0, 'advert'),
#  (1.0, 'adrenaline'),
#  (1.0, 'ad'),
#  (1.0, 'ad'),
#  (1.0, 'actually'),
#  (1.0, 'actually'),
#  (1.0, 'acquiring'),
#  (1.0, 'accomplish'),
#  (1.0, 'abstract'),
#  (1.0, '8f'),
#  (1.0, '25ths'),
#  (1.0, '2021'),
#  (1.0, '1980s'),
#  (1.0, '1600'),
#  (1.0, '1')]

# %%
url = "https://www.35mmc.com/13/10/2022/alfie-tych-preview-an-eccentric-camera-that-fits-in-the-palm-of-your-hand/"
get_kw(open_html_35mmc(url))
# Out:
# Keyphrase:  Alfie Tych : score 0.0017164076053065272
# Keyphrase:  Camera : score 0.0032664162426386863
# Keyphrase:  Tych : score 0.0058462433100626736
# Keyphrase:  lens : score 0.008474931452216618
# Keyphrase:  Alfie : score 0.00929127421502871
# Keyphrase:  disposable camera lens : score 0.010625390113747928
# Keyphrase:  Alfie Tych Preview : score 0.011211835440508503
# Keyphrase:  Shoot Alfie Tych : score 0.013540785050423691
# Keyphrase:  camera lens : score 0.013649272452933467
# Keyphrase:  Alfie Tych launched : score 0.01591158839884314
# Keyphrase:  Alfie Tych Half : score 0.01615457401906576
# Keyphrase:  small camera : score 0.022864732120952726
# Keyphrase:  Cameras : score 0.022864913698470806
# Keyphrase:  Dave : score 0.023304029811982752
# Keyphrase:  disposable camera : score 0.027311445403383178
# Keyphrase:  Alfie Cameras : score 0.02750419854847145
# Keyphrase:  pinhole : score 0.02913083557484601
# Keyphrase:  shutter : score 0.03213309007300044
# Keyphrase:  pinhole cameras : score 0.032261847803703815
# Keyphrase:  Alfie Point : score 0.035951032249353365

# %%
url = "https://www.35mmc.com/14/10/2021/pentax-iqzoom-928-review/"
get_kw(open_html_35mmc(url))
# Out:
# Keyphrase:  Pentax IQZoom : score 0.0034720617421485677
# Keyphrase:  IQZoom : score 0.010908060378340833
# Keyphrase:  Pentax : score 0.01256896635931791
# Keyphrase:  cameras : score 0.015051844880593987
# Keyphrase:  camera : score 0.023261942088190705
# Keyphrase:  film : score 0.03798410253178397
# Keyphrase:  mode : score 0.03921821006392998
# Keyphrase:  n’t : score 0.0439093014979266
# Keyphrase:  ’ve : score 0.07125920557630984
# Keyphrase:  Pentax Point : score 0.08737647428428813
# Keyphrase:  compacts : score 0.08853453690879917
# Keyphrase:  mechanical cameras : score 0.0942698736147433
# Keyphrase:  Shoot : score 0.0960560143428515
# Keyphrase:  zoom : score 0.09980142809851919
# Keyphrase:  Oregon : score 0.1026849641815409
# Keyphrase:  Point : score 0.10655253086658086
# Keyphrase:  Shoot camera : score 0.10903570542015223
# Keyphrase:  compact : score 0.11066817113599896
# Keyphrase:  lens : score 0.11845236928820999
# Keyphrase:  Espio : score 0.12393323284191114

# %%
url = "https://pantip.com/topic/41687081"
get_kw(open_html_pantip(url))
# Out:
# Keyphrase:  Holy Trinity Cathedral : score 0.00033918737020522944
# Keyphrase:  Trinity Cathedral ครับ : score 0.0016020837759328996
# Keyphrase:  Trinity Cathedral : score 0.0027615816590871706
# Keyphrase:  Holy Trinity : score 0.002974516283469105
# Keyphrase:  Ananuri Castle Complex : score 0.003081711084682901
# Keyphrase:  Bath Narikala Fortress : score 0.0031141946145948384
# Keyphrase:  Gergeti Trinity Church : score 0.003228225345076582
# Keyphrase:  Sulphur Bath Narikala : score 0.0036919133000353987
# Keyphrase:  Narikala Fortress Cable : score 0.003816708730380757
# Keyphrase:  Trinity Cathedral ที่อยู่ตรงข้ามโรงแรมครับ : score 0.005041903204254575
# Keyphrase:  กับ Holy Trinity : score 0.005448256912846404
# Keyphrase:  (เลือกเพราะอยู่ใกล้ Holy Trinity : score 0.005448256912846404
# Keyphrase:  เริ่มจาก Holy Trinity : score 0.005448256912846404
# Keyphrase:  Narikala Fortress ครับ : score 0.005516409091046977
# Keyphrase:  Fortress Cable Car : score 0.005558981125255761
# Keyphrase:  Narikala Fortress : score 0.006248809421420372
# Keyphrase:  Wood House Gergeti : score 0.006975139219319737
# Keyphrase:  วิวจาก Narikala Fortress : score 0.00875297930353477
# Keyphrase:  EPIC Hotel ครับ : score 0.009243396460616792
# Keyphrase:  Castle Complex ครับ : score 0.009627098336498243

# %%
from keybert import KeyBERT

# %%
doc = """
    Computer Science is the study of computers and computational systems.
    Unlike electrical and computer engineers, computer scientists deal mostly
    with software and software systems; this includes their theory, design,
    development, and application. Principal areas of study within Computer
    Science include artificial intelligence, computer systems and networks,
    security, database systems, human computer interaction, vision and graphics,
    numerical analysis, programming languages, software engineering, bioinformatics
    and theory of computing. Although knowing how to program is essential to
    the study of computer science, it is only one element of the field. Computer
    scientists design and analyze algorithms to solve programs and study the
    performance of computer hardware and software. The problems that computer
    scientists encounter range from the abstract-- determining what problems
    can be solved with computers and the complexity of the algorithms that
    solve them – to the tangible – designing applications that perform well
    on handheld devices, that are easy to use, and that uphold security measures.
"""

kw_model = KeyBERT()
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 2))
print(keywords)
# Out:
# [('computer science', 0.6847), ('computer scientists', 0.6655), ('computers computational', 0.5813), ('computer engineers', 0.5612), ('study computers', 0.5589)]

# %%
# !python -m ensurepip --upgrade
# Out:
# Looking in links: c:\Users\aingt\AppData\Local\Temp\tmp86shg1rh
# Requirement already satisfied: setuptools in c:\users\aingt\anaconda3\lib\site-packages (63.4.1)
# Requirement already satisfied: pip in c:\users\aingt\anaconda3\lib\site-packages (22.2.2)
