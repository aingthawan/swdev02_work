# %%
# import concurrent.futures
# import requests
# from bs4 import BeautifulSoup

# def crawl_level(url, level):
#     if level <= 3:
#         print("Crawling level : ", level)
#         webReq = requests.get(url)
#         soup_obj = BeautifulSoup(webReq.text, "html.parser")
#         print(soup_obj.find('h1', {'class':'entry-title'}).text)
#         return [i.find('a')['href'] for i in soup_obj.find_all('div', {'class':'sp-col-4'})]
#     else:
#         return []

# def crawl_3level(url, level):
#     links = crawl_level(url, level)
#     # parallel scraping
#     with concurrent.futures.ThreadPoolExecutor() as executor:
#         future_to_url = {executor.submit(crawl_3level, link, level+1): link for link in links}
#         for future in concurrent.futures.as_completed(future_to_url):
#             url = future_to_url[future]
#             try:
#                 future.result()
#             except Exception as exc:
#                 print('%r generated an exception: %s' % (url, exc))

# %%
# A code to scrape name from 35mmc.com
# scrape for a defined level
# Aing KK.

from tqdm import tqdm
import concurrent.futures
import requests
from bs4 import BeautifulSoup
import mysql.connector
import time

# %%
def crawl_level(db, url, level):
    # depth limit for crawling url
    if level <= 20:
        webReq = requests.get(url)
        soup_obj = BeautifulSoup(webReq.text, "html.parser")
        raw_text = soup_obj.find('article').text
        # get title
        get_title = soup_obj.find('h1', {'class':'entry-title'}).text
        print("Current level : ", level, " at : ", get_title)
        # store to db
        db.store_db(get_title, url, raw_text)
        # time.sleep(0.500)
        return [i.find('a')['href'] for i in soup_obj.find_all('div', {'class':'sp-col-4'})]
    else:
        return []

# %%
# def crawl_3level(db, url, level):
#     links = crawl_level(db, url, level)
#     # parallel scraping
#     with concurrent.futures.ThreadPoolExecutor() as executor:
#         future_to_url = {executor.submit(crawl_3level, db, link, level+1): link for link in links}
#         for future in concurrent.futures.as_completed(future_to_url):
#             url = future_to_url[future]
#             try:
#                 future.result()
#             except Exception as exc:
#                 print('%r generated an exception: %s' % (url, exc))
                
def crawl_3level(db, url, level):
    for link in crawl_level(db, url, level):
        crawl_3level(db, link, level+1)
    print("level : ", level, " Completed")

# %%
class databasePipeline:
    def __init__(self, host, user, password, database, table_name):
        print("Initialize Database Pipeline")
        self.host = host
        self.user = user
        self.password = password
        self.database = database
        self.table_name = table_name
        self.create_connection()
        self.curr = self.conn.cursor()
        self.create_table()

    def create_connection(self):
        """Create a connection to the database"""
        print("Creating Connection . . .")
        self.conn = mysql.connector.connect(
            host=self.host,
            user=self.user,
            password=self.password,
            database=self.database
        )
        print("Connceted.")
    
    def create_table(self):
        print("Creating table . . .")
        self.curr.execute("""DROP TABLE IF EXISTS 35mmc_raw""")
        self.curr.execute("""create table 35mmc_raw(
            title text,
            url text,
            raw_text text
        )""")
        print("Done Table.")

    def store_db(self, title, url, raw_text):
        self.curr.execute(
            """INSERT INTO {} (title, url, raw_text) VALUES (%s, %s, %s)""".format(self.table_name),
            (title, url, raw_text)
        )
        self.conn.commit()

# %%
start_url = 'https://www.35mmc.com/20/05/2016/halina-af700-review/'

# %%
db = databasePipeline('localhost', 'root', 'aingg', '35mmc', '35mmc_raw')
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# Current level :  20  at :  Samsung AF Slim – one roll review
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# Current level :  20  at :  Ricoh FF90 Review – The camera that got in a fight with 80’s style, and lost!
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# level :  19  Completed
# Current level :  19  at :  Leica Mini – One roll review
# Current level :  20  at :  Ricoh Mirai & Olympus AZ-4 Zoom Review – Fraternal Twins – By David Tellet
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# Current level :  20  at :  Nikon AF3 – One roll review
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# Current level :  20  at :  Olympus mju-V Metal Review – Not So Famous Last Words – By Octavia Vans
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# level :  19  Completed
# Current level :  19  at :  Vivitar Ultra Wide and Slim – Modifying & Shooting – by Charles Higham
# Current level :  20  at :  Pentax Espio 120 – 1/3rd roll review
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# Current level :  20  at :  Olympus iS-300 Bridge Camera Mini Review – 7 frames with a 1990s ‘Grandpa Chic’ Camera – Matthew Bigwood
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# Current level :  20  at :  Yashica T2 Review: A Noisy Companion – by John Lee
# level :  21  Completed
# level :  21  Completed
# level :  21  Completed
# level :  20  Completed
# level :  19  Completed
# level :  18  Completed
# level :  17  Completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17128\1705450948.py in <module>
#       1 start_level = 1
# ----> 2 crawl_3level(db, start_url, start_level)
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      13 def crawl_3level(db, url, level):
#      14     for link in crawl_level(db, url, level):
# ---> 15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#      17
#
# ~\AppData\Local\Temp\ipykernel_17128\1142376155.py in crawl_3level(db, url, level)
#      12
#      13 def crawl_3level(db, url, level):
# ---> 14     for link in crawl_level(db, url, level):
#      15         crawl_3level(db, link, level+1)
#      16     print("level : ", level, " Completed")
#
# ~\AppData\Local\Temp\ipykernel_17128\3120262310.py in crawl_level(db, url, level)
#       4         webReq = requests.get(url)
#       5         soup_obj = BeautifulSoup(webReq.text, "html.parser")
# ----> 6         raw_text = soup_obj.find('article').text
#       7         # get title
#       8         get_title = soup_obj.find('h1', {'class':'entry-title'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'
