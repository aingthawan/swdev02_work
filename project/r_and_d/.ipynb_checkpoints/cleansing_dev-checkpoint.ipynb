# %%
from tqdm import tqdm
import concurrent.futures
import requests
from bs4 import BeautifulSoup
import mysql.connector
import time

# %%
url = 'https://www.35mmc.com/26/09/2016/leica-c2-zoom-review/'

# %%
webReq = requests.get(url)
soup_obj = BeautifulSoup(webReq.text, "html.parser")
if soup_obj.find('article').text != None:
    raw_text = soup_obj.find('article').text
    # get title
    get_title = soup_obj.find('h1', {'class':'entry-title'}).text

# %%
import re
import spacy
from nltk.corpus import stopwords

class TextCleaner:
    """Designed for Inverted Indexing"""
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")
        self.stop_words = set(stopwords.words('english'))

    def normalize(self, raw_text):
        """Remove special characters and lowercase text"""
        return re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", " ", raw_text.lower())

    def remove_stopwords(self, raw_text):
        """Remove stopwords"""
        words = [word for word in raw_text.split() if word not in self.stop_words]
        return " ".join(words)

    def lemmatize(self, raw_text):
        """Perform lemmatization"""
        doc = self.nlp(raw_text)
        return [token.lemma_ for token in doc]

    def clean(self, raw_text):
        """Clean text by normalizing, removing stopwords, and lemmatizing, Returning a list of token"""
        raw_text = self.normalize(raw_text)
        raw_text = self.remove_stopwords(raw_text)
        return self.lemmatize(raw_text)

# %%
clean = TextCleaner()
clean.clean(webReq.text)
# Out:
# ['doctype',
#  'html',
#  'html',
#  'lang',
#  'en',
#  'we',
#  'head',
#  'meta',
#  'charset',
#  'utf',
#  '8',
#  'script',
#  'datum',
#  'ezscrex',
#  'false',
#  'datum',
#  'cfasync',
#  'false',
#  'datum',
#  'pagespeed',
#  'defer',
#  'var',
#  'ez',
#  'ez',
#  'ez',
#  'stms',
#  'date',
#  'ez',
#  'evt',
#  'ez',
#  'script',
#  'ez',
#  'ck',
#  'ez',
#  'ck',
#  'ez',
#  'template',
#  'ez',
#  'template',
#  'isorig',
#  'true',
#  'ez',
#  'queue',
#  'function',
#  'var',
#  'e',
#  '0',
#  '0',
#  'n',
#  '1',
#  'r',
#  '0',
#  'function',
#  'e',
#  'n',
#  'r',
#  'var',
#  'l',
#  'name',
#  'e',
#  'funcname',
#  'parameter',
#  'null',
#  'n',
#  'null',
#  'n',
#  'instanceof',
#  'array',
#  'n',
#  'n',
#  'isblock',
#  'blockedby',
#  'r',
#  'deletewhencomplete',
#  'iserror',
#  '1',
#  'iscomplete',
#  '1',
#  'isinitialize',
#  '1',
#  'proceediferror',
#  'istimedelay',
#  '1',
#  'process',
#  'function',
#  'u',
#  'func',
#  'e',
#  'l',
#  'isinitialize',
#  '0',
#  'l',
#  'iscomplete',
#  '0',
#  'u',
#  'func',
#  'apply',
#  'e',
#  'var',
#  'l',
#  'funcname',
#  'split',
#  'n',
#  'null',
#  'length',
#  '3',
#  'n',
#  '3',
#  'length',
#  'window',
#  '0',
#  '1',
#  '2',
#  '2',
#  'length',
#  'window',
#  '0',
#  '1',
#  'window',
#  'l',
#  'funcname',
#  'null',
#  'n',
#  'n',
#  'apply',
#  'null',
#  'parameter',
#  '0',
#  'l',
#  'deletewhencomplete',
#  'delete',
#  'e',
#  '0',
#  'l',
#  'isblock',
#  'u',
#  'f',
#  'l',
#  'name',
#  'f',
#  'l',
#  'function',
#  'e',
#  'n',
#  'r',
#  'var',
#  'name',
#  'e',
#  'path',
#  'async',
#  'defer',
#  'r',
#  'isblock',
#  'blockedby',
#  'n',
#  'isinitialize',
#  '1',
#  'iserror',
#  '1',
#  'iscomplete',
#  '1',
#  'proceediferror',
#  'istimedelay',
#  '1',
#  'ispath',
#  'function',
#  'e',
#  'return',
#  'e',
#  '0',
#  'e',
#  '1',
#  'getsrc',
#  'function',
#  'e',
#  'return',
#  'void',
#  '0',
#  'window',
#  'ezscripthost',
#  'ispath',
#  'e',
#  'window',
#  'ezscripthost',
#  'e',
#  'e',
#  'process',
#  'function',
#  'isinitialize',
#  '0',
#  'u',
#  'file',
#  'e',
#  'var',
#  'document',
#  'createelement',
#  'script',
#  'src',
#  'getsrc',
#  'path',
#  '0',
#  'async',
#  '0',
#  '0',
#  'r',
#  'defer',
#  '0',
#  'onerror',
#  'function',
#  'u',
#  'err',
#  'name',
#  'iserror',
#  '0',
#  '0',
#  'isblock',
#  'f',
#  'onreadystatechange',
#  'onload',
#  'function',
#  'var',
#  'e',
#  'readystate',
#  'u',
#  'f',
#  'name',
#  'e',
#  'load',
#  'complete',
#  'test',
#  'e',
#  'iscomplete',
#  '0',
#  '0',
#  'isblock',
#  'f',
#  'document',
#  'getelementsbytagname',
#  'head',
#  '0',
#  'appendchild',
#  'c',
#  'function',
#  'e',
#  'name',
#  'e',
#  'path',
#  'async',
#  '1',
#  'defer',
#  '1',
#  'isblock',
#  '1',
#  'blockedby',
#  'isinitialize',
#  '0',
#  'iserror',
#  '1',
#  'iscomplete',
#  'proceediferror',
#  '1',
#  'istimedelay',
#  '1',
#  'process',
#  'function',
#  'function',
#  'e',
#  '0',
#  'h',
#  'e',
#  '0',
#  'e',
#  'process',
#  'function',
#  'h',
#  'e',
#  '0',
#  'e',
#  'istimedelay',
#  '1',
#  'n',
#  'return',
#  'u',
#  'e',
#  'name',
#  'block',
#  'time',
#  'delay',
#  '0',
#  'e',
#  'blockedby',
#  'instanceof',
#  'array',
#  'var',
#  '0',
#  'e',
#  'blockedby',
#  'length',
#  'var',
#  'e',
#  'blockedby',
#  '1',
#  'hasownproperty',
#  'return',
#  'u',
#  'e',
#  'name',
#  'block',
#  '0',
#  '0',
#  'e',
#  'proceediferror',
#  '0',
#  'iserror',
#  'return',
#  '1',
#  '1',
#  'iscomplete',
#  'return',
#  'u',
#  'e',
#  'name',
#  'block',
#  '0',
#  'return',
#  '1',
#  'function',
#  'u',
#  'e',
#  'var',
#  'window',
#  'location',
#  'href',
#  'new',
#  'regexp',
#  'ezq',
#  'exec',
#  '1',
#  '1',
#  'null',
#  'console',
#  'debug',
#  'e',
#  'function',
#  'f',
#  'e',
#  '200',
#  'u',
#  'let',
#  'go',
#  'r',
#  'function',
#  'e',
#  'var',
#  'e',
#  '1',
#  'e',
#  'hasownproperty',
#  'var',
#  'e',
#  '0',
#  'iscomplete',
#  'h',
#  '0',
#  'isinitialize',
#  '0',
#  'iserror',
#  '0',
#  'iserror',
#  'u',
#  'name',
#  'error',
#  '0',
#  'iscomplete',
#  'u',
#  'name',
#  'complete',
#  'already',
#  '0',
#  'isinitialize',
#  'u',
#  'name',
#  'initialize',
#  'already',
#  'process',
#  'return',
#  'window',
#  'addeventlistener',
#  'load',
#  'function',
#  'settimeout',
#  'function',
#  'n',
#  '0',
#  'u',
#  'tdelay',
#  'f',
#  '5e3',
#  '1',
#  'addfile',
#  'function',
#  'e',
#  'n',
#  'c',
#  'h',
#  'u',
#  'var',
#  'f',
#  'new',
#  'l',
#  'e',
#  'n',
#  'c',
#  'h',
#  '0',
#  'u',
#  'e',
#  'f',
#  'r',
#  'e',
#  'f',
#  'e',
#  'f',
#  'f',
#  'adddelayfile',
#  'function',
#  'e',
#  'var',
#  'n',
#  'new',
#  'l',
#  'e',
#  '1',
#  '1',
#  '1',
#  '0',
#  'n',
#  'istimedelay',
#  '0',
#  'u',
#  'e',
#  'file',
#  'tdelay',
#  'r',
#  'e',
#  'n',
#  'e',
#  'n',
#  'n',
#  'addfunc',
#  'function',
#  'e',
#  'n',
#  'l',
#  'c',
#  'h',
#  'u',
#  'f',
#  '0',
#  'h',
#  'e',
#  'e',
#  'var',
#  'p',
#  'new',
#  'e',
#  'n',
#  'l',
#  'c',
#  'u',
#  'f',
#  '0',
#  'e',
#  'p',
#  'r',
#  'e',
#  'p',
#  'e',
#  'p',
#  'p',
#  'adddelayfunc',
#  'function',
#  'e',
#  'n',
#  'var',
#  'new',
#  'e',
#  'n',
#  '1',
#  '0',
#  '0',
#  'istimedelay',
#  '0',
#  'u',
#  'e',
#  'function',
#  'tdelay',
#  'r',
#  'e',
#  'e',
#  'item',
#  'processall',
#  'f',
#  'setallowload',
#  'function',
#  'e',
#  'e',
#  'markloade',
#  'function',
#  'e',
#  'e',
#  '0',
#  'e',
#  'length',
#  'e',
#  'var',
#  'e',
#  '0',
#  'iscomplete',
#  'u',
#  'name',
#  'e',
#  'error',
#  'load',
#  'duplicate',
#  'iscomplete',
#  '0',
#  'isinitialize',
#  '0',
#  'else',
#  'e',
#  'new',
#  'c',
#  'e',
#  '0',
#  'u',
#  'markloaded',
#  'dummyfile',
#  'e',
#  'name',
#  'logwhatsblocke',
#  'function',
#  'var',
#  'e',
#  '1',
#  'hasownproperty',
#  'e',
#  'h',
#  'e',
#  'ez',
#  'evt',
#  'add',
#  'function',
#  'e',
#  'n',
#  'e',
#  'addeventlistener',
#  'e',
#  'addeventlistener',
#  'n',
#  '1',
#  'e',
#  'attachevent',
#  'e',
#  'attachevent',
#  'n',
#  'e',
#  'n',
#  'ez',
#  'evt',
#  'remove',
#  'function',
#  'e',
#  'n',
#  'e',
#  'removeeventlistener',
#  'e',
#  'removeeventlistener',
#  'n',
#  '1',
#  'e',
#  'detachevent',
#  'e',
#  'detachevent',
#  'n',
#  'delete',
#  'e',
#  'ez',
#  'script',
#  'add',
#  'function',
#  'e',
#  'var',
#  'document',
#  'createelement',
#  'script',
#  'src',
#  'e',
#  'async',
#  '0',
#  'type',
#  'text',
#  'javascript',
#  'document',
#  'getelementsbytagname',
#  'head',
#  '0',
#  'appendchild',
#  'ez',
#  'dot',
#  'ez',
#  'queue',
#  'addfile',
#  'detroitchicago',
#  'boise',
#  'js',
#  'detroitchicago',
#  'boise',
#  'js',
#  'gcb',
#  '195',
#  '14',
#  'cb',
#  '2',
#  'true',
#  'true',
#  'false',
#  'true',
#  'false',
#  'ez',
#  'queue',
#  'addfile',
#  'detroitchicago',
#  'memphis',
#  'js',
#  'detroitchicago',
#  'memphis',
#  'js',
#  'gcb',
#  '195',
#  '14',
#  'cb',
#  '23',
#  'true',
#  'true',
#  'false',
#  'true',
#  'false',
#  'ez',
#  'queue',
#  'addfile',
#  'detroitchicago',
#  'minneapolis',
#  'js',
#  'detroitchicago',
#  'minneapolis',
#  'js',
#  'gcb',
#  '195',
#  '14',
#  'cb',
#  '4',
#  'true',
#  'true',
#  'false',
#  'true',
#  'false',
#  'ez',
#  'queue',
#  'addfile',
#  'detroitchicago',
#  'rochester',
#  'js',
#  'detroitchicago',
#  'rochester',
#  'js',
#  'gcb',
#  '195',
#  '14',
#  'cb',
#  '13',
#  'false',
#  'detroitchicago',
#  'memphis',
#  'js',
#  'detroitchicago',
#  'minneapolis',
#  'js',
#  'true',
#  'false',
#  'true',
#  'false',
#  'function',
#  'var',
#  'e',
#  'ez',
#  'vep',
#  'e',
#  'add',
#  'function',
#  'ez',
#  'dot',
#  'isdefine',
#  'ez',
#  'dot',
#  'isvalid',
#  'e',
#  'push',
#  'type',
#  'video',
#  'video',
#  'impression',
#  'i',
#  'd',
#  'domain',
#  'i',
#  'd',
#  'ez',
#  'dot',
#  'getdid',
#  'epoch',
#  'ez',
#  'dot',
#  'getepoch',
#  '0',
#  'datum',
#  'ez',
#  'dot',
#  'datatostr',
#  'fire',
#  'function',
#  'void',
#  '0',
#  'document',
#  'visibilitystate',
#  'prerender',
#  'document',
#  'visibilitystate',
#  'ez',
#  'dot',
#  'isdefine',
#  'e',
#  'e',
#  'length',
#  '0',
#  'e',
#  'length',
#  '0',
#  'var',
#  '5',
#  'e',
#  'length',
#  'e',
#  'length',
#  'var',
#  'e',
#  'splice',
#  '0',
#  'ez',
#  'dot',
#  'geturl',
#  'detroitchicago',
#  'grapefruit',
#  'gif',
#  'orig',
#  '0',
#  'ez',
#  'template',
#  'isorig',
#  '1',
#  '0',
#  'v',
#  'btoa',
#  'json',
#  'stringify',
#  'ez',
#  'dot',
#  'fire',
#  'e',
#  'script',
#  'script',
#  'data',
#  'ezscrex',
#  'false',
#  'datum',
#  'cfasync',
#  'false',
#  'datum',
#  'pagespeed',
#  'defer',
#  'function',
#  'function',
#  'e',
#  'return',
#  'e',
#  'function',
#  'typeof',
#  'symbol',
#  'symbol',
#  'typeof',
#  'symbol',
#  'iterator',
#  'function',
#  'e',
#  'return',
#  'typeof',
#  'e',
#  'function',
#  'e',
#  'return',
#  'e',
#  'function',
#  'typeof',
#  'symbol',
#  'e',
#  'constructor',
#  'symbol',
#  'e',
#  'symbol',
#  'prototype',
#  'symbol',
#  'typeof',
#  'e',
#  'e',
#  'ez',
#  'pel',
#  'function',
#  'var',
#  'function',
#  'n',
#  'r',
#  'ez',
#  'dot',
#  'isdefine',
#  '0',
#  'ez',
#  'dot',
#  'isanydefine',
#  'getslotelementid',
#  'elementid',
#  'void',
#  '0',
#  '1',
#  'var',
#  'p',
#  'parseint',
#  'ez',
#  'dot',
#  'gettargeting',
#  'ap',
#  'f',
#  'ez',
#  'dot',
#  'getslotiid',
#  'u',
#  'ez',
#  'dot',
#  'getadunit',
#  'z',
#  'parseint',
#  'ez',
#  'dot',
#  'gettargeting',
#  'compid',
#  'g',
#  '0',
#  'c',
#  '0',
#  'l',
#  'function',
#  'undefine',
#  'typeof',
#  'ezim',
#  'return',
#  '1',
#  'var',
#  'ez',
#  'dot',
#  'getadunitpath',
#  'split',
#  'pop',
#  'object',
#  'undefine',
#  'typeof',
#  'ezim',
#  'undefine',
#  'e',
#  'ezim',
#  'ezim',
#  'hasownproperty',
#  'return',
#  'ezim',
#  'var',
#  'ezim',
#  'split',
#  'pop',
#  'return',
#  'ezim',
#  'return',
#  '1',
#  'object',
#  'e',
#  'l',
#  'void',
#  '0',
#  'l',
#  'creative',
#  'i',
#  'd',
#  'c',
#  'l',
#  'creative',
#  'i',
#  'd',
#  'void',
#  '0',
#  'l',
#  'line',
#  'item',
#  'i',
#  'd',
#  'g',
#  'l',
#  'line',
#  'item',
#  'i',
#  'd',
#  'ez',
#  'dot',
#  'isdefine',
#  'f',
#  'u',
#  'ez',
#  'dot',
#  'isvalid',
#  '0',
#  'f',
#  '0',
#  'u',
#  'push',
#  'type',
#  'impression',
#  'impression',
#  'i',
#  'd',
#  'f',
#  'domain',
#  'I',
#  'd',
#  'ez',
#  'dot',
#  'getdid',
#  'unit',
#  'u',
#  'epoch',
#  'ez',
#  'dot',
#  'getepoch',
#  '0',
#  'revenue',
#  'est',
#  'revenue',
#  'ad',
#  'position',
#  'p',
#  'ad',
#  'size',
#  'bid',
#  'floor',
#  'fill',
#  'n',
#  'bid',
#  'floor',
#  'prev',
#  'r',
#  'stat',
#  'source',
#  'i',
#  'd',
#  'country',
#  'code',
#  'ez',
#  'dot',
#  'getcc',
#  'pageview',
#  'i',
#  'd',
#  'ez',
#  'dot',
#  'getpageviewid',
#  'comp',
#  'i',
#  'd',
#  'z',
#  'line',
#  'item',
#  'i',
#  'd',
#  'g',
#  'creative',
#  ...]

# %%
get_title
# Out:
# 'Leica C2 Zoom Review – A Mind of Its Own – by Torsten Kathke'

# %% [markdown]
# # Normalize Text

# %%
raw_text_norm = raw_text.lower()
raw_text_norm
# Out:
# '\n\n \n\npoint & shoot\nleica c2 zoom review – a mind of its own – by torsten kathke\nseptember 26, 2016\n\n\nthe dream is that someone will just give you a leica. the dream is alive. well, at least it is not completely dead. i was given a leica c2 zoom.\na few months ago, a friend and colleague of mine made an intervention with her mother, who had decided, after sifting through a family member’s collection of things, to keep the nikon slr but trash the lesser cameras. a co-conspirator in the visual arts, my friend pointed out that she might know someone who could use these unwanted things. this is how one monday in june, i found two cameras and several camera-related odds and ends on my desk at work.\none of the cameras was a ridiculously well-built voigtländer rangefinder from the 1950s. the other was a plastic point and shoot from the 1990s.\xa0of course i will review the plastic point and shoot first. i mean, who wants to hear yet again about quality workmanship from a period before skimping was the rule in camera construction and that we don’t build things anymore, and the country’s going down the tubes, what country, doesn’t matter, all of them, no one bothers anymore and that is precisely why everything sucks and attention spans and instagram; the internet, kids, the internet! right? i mean, right?\nbut even if you do want to hear about such cameras, i trust the voigtländer will easily survive another hundred years or so. plenty of time to review that one later on. the plastic point and shoot, on the other hand, will only be good for as long as its electronics keep working. maybe that’s a hundred years. maybe it’s a week and a half. maybe it will surprise us all and become queen of the robots when they finally and inevitably rise. i do not know the future. what i do know is that today, plastic is where it’s at. love the plastic. embrace the plastic. you shall worship at its altar. made of plastic.\nbunnies, bunnies, it must be bunnies! (slightly soft corners and some chromatic aberrations visible).\na plastic leicacontents1 a plastic leica2 the leica c22.1 auto zoom2.2 the lens2.3 framing2.4 the flash2.5 dx reading2.6 remote control3 conclusions\nmy decision in favour of the plastic camera was helped along by the presence of a coveted little red dot with five letters in calligraphic white writing on the camera: leica. so here i was. having reached my thirties with most of my faculties intact, having bought and used dozens of cameras, having written about them, having liked and loved some and not others: i had a leica. a leica, you guys. the definitive camera of a century. the camera that had changed everything for photojournalism. made of plastic.\nthe leica c2\nso the leica c2 zoom is maybe not on the same higher plane as a built-to-order leica mp. it was never meant to be. it was supposed to fill a spot below the m series leicas in the early 1990s. a spot that at some point had been occupied by the all-too successful leica cl. the zoom range of the c2 is a clue here: it goes from 40mm, the leica cl’s standard lens focal length, to 90mm, the focal length of the cl’s other dedicated lens. the zoom starts at an acceptable f3.5 at the 40mm end, but by 90mm only a narrow f7.7 remains. the leica also came with a real leather bag, which means it’s still a usable bag today, not plagued by the deterioration of whatever cheap material was used\xa0that so many other camera bags and cases from the 70s onward have.\nfyi: there is a date-back version of the c2 zoom if you’re inclined to go full-on 90s and put the date on the image area of your pictures. this, while not an altogether bad idea, is usually implemented badly, as it is on the c2 zoom. if it’s on, it’s always on. that blasted date is on every picture. a smarter way to do this would be do let the camera put a date on the first picture of the day, and then not on subsequent images until the date actually changes. but that’s how i want to use it today, not how people used  ...

# %% [markdown]
# # Clear Unicode

# %%
import re

raw_text_norm_uni = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", " ", raw_text_norm)

raw_text_norm_uni
# Out:
# '     point   shoot leica c2 zoom review   a mind of its own   by torsten kathke september 26  2016   the dream is that someone will just give you a leica  the dream is alive  well  at least it is not completely dead  i was given a leica c2 zoom  a few months ago  a friend and colleague of mine made an intervention with her mother  who had decided  after sifting through a family member s collection of things  to keep the nikon slr but trash the lesser cameras  a co conspirator in the visual arts  my friend pointed out that she might know someone who could use these unwanted things  this is how one monday in june  i found two cameras and several camera related odds and ends on my desk at work  one of the cameras was a ridiculously well built voigtl nder rangefinder from the 1950s  the other was a plastic point and shoot from the 1990s  of course i will review the plastic point and shoot first  i mean  who wants to hear yet again about quality workmanship from a period before skimping was the rule in camera construction and that we don t build things anymore  and the country s going down the tubes  what country  doesn t matter  all of them  no one bothers anymore and that is precisely why everything sucks and attention spans and instagram  the internet  kids  the internet  right  i mean  right  but even if you do want to hear about such cameras  i trust the voigtl nder will easily survive another hundred years or so  plenty of time to review that one later on  the plastic point and shoot  on the other hand  will only be good for as long as its electronics keep working  maybe that s a hundred years  maybe it s a week and a half  maybe it will surprise us all and become queen of the robots when they finally and inevitably rise  i do not know the future  what i do know is that today  plastic is where it s at  love the plastic  embrace the plastic  you shall worship at its altar  made of plastic  bunnies  bunnies  it must be bunnies   slightly soft corners and some chromatic aberrations visible   a plastic leicacontents1 a plastic leica2 the leica c22 1 auto zoom2 2 the lens2 3 framing2 4 the flash2 5 dx reading2 6 remote control3 conclusions my decision in favour of the plastic camera was helped along by the presence of a coveted little red dot with five letters in calligraphic white writing on the camera  leica  so here i was  having reached my thirties with most of my faculties intact  having bought and used dozens of cameras  having written about them  having liked and loved some and not others  i had a leica  a leica  you guys  the definitive camera of a century  the camera that had changed everything for photojournalism  made of plastic  the leica c2 so the leica c2 zoom is maybe not on the same higher plane as a built to order leica mp  it was never meant to be  it was supposed to fill a spot below the m series leicas in the early 1990s  a spot that at some point had been occupied by the all too successful leica cl  the zoom range of the c2 is a clue here  it goes from 40mm  the leica cl s standard lens focal length  to 90mm  the focal length of the cl s other dedicated lens  the zoom starts at an acceptable f3 5 at the 40mm end  but by 90mm only a narrow f7 7 remains  the leica also came with a real leather bag  which means it s still a usable bag today  not plagued by the deterioration of whatever cheap material was used that so many other camera bags and cases from the 70s onward have  fyi  there is a date back version of the c2 zoom if you re inclined to go full on 90s and put the date on the image area of your pictures  this  while not an altogether bad idea  is usually implemented badly  as it is on the c2 zoom  if it s on  it s always on  that blasted date is on every picture  a smarter way to do this would be do let the camera put a date on the first picture of the day  and then not on subsequent images until the date actually changes  but that s how i want to use it today  not how people used it in the 1990s  they ju ...

# %% [markdown]
# # Remove stopwords + tokenize

# %%
# with nltk
import nltk.corpus as nltkc

stopwords = set(nltkc.stopwords.words('english'))
# tokenized
raw_text_norm_uni_stopnltk_token = []

for word in raw_text_norm_uni.split():
    if word not in stopwords:
        raw_text_norm_uni_stopnltk_token.append(word)

# joined
raw_text_norm_uni_stopnltk_join = " ".join(raw_text_norm_uni_stopnltk_token)

raw_text_norm_uni_stopnltk_join
# Out:
# 'point shoot leica c2 zoom review mind torsten kathke september 26 2016 dream someone give leica dream alive well least completely dead given leica c2 zoom months ago friend colleague mine made intervention mother decided sifting family member collection things keep nikon slr trash lesser cameras co conspirator visual arts friend pointed might know someone could use unwanted things one monday june found two cameras several camera related odds ends desk work one cameras ridiculously well built voigtl nder rangefinder 1950s plastic point shoot 1990s course review plastic point shoot first mean wants hear yet quality workmanship period skimping rule camera construction build things anymore country going tubes country matter one bothers anymore precisely everything sucks attention spans instagram internet kids internet right mean right even want hear cameras trust voigtl nder easily survive another hundred years plenty time review one later plastic point shoot hand good long electronics keep working maybe hundred years maybe week half maybe surprise us become queen robots finally inevitably rise know future know today plastic love plastic embrace plastic shall worship altar made plastic bunnies bunnies must bunnies slightly soft corners chromatic aberrations visible plastic leicacontents1 plastic leica2 leica c22 1 auto zoom2 2 lens2 3 framing2 4 flash2 5 dx reading2 6 remote control3 conclusions decision favour plastic camera helped along presence coveted little red dot five letters calligraphic white writing camera leica reached thirties faculties intact bought used dozens cameras written liked loved others leica leica guys definitive camera century camera changed everything photojournalism made plastic leica c2 leica c2 zoom maybe higher plane built order leica mp never meant supposed fill spot series leicas early 1990s spot point occupied successful leica cl zoom range c2 clue goes 40mm leica cl standard lens focal length 90mm focal length cl dedicated lens zoom starts acceptable f3 5 40mm end 90mm narrow f7 7 remains leica also came real leather bag means still usable bag today plagued deterioration whatever cheap material used many camera bags cases 70s onward fyi date back version c2 zoom inclined go full 90s put date image area pictures altogether bad idea usually implemented badly c2 zoom always blasted date every picture smarter way would let camera put date first picture day subsequent images date actually changes want use today people used 1990s prints made prints got mixed given away wanted know every print day well portrait truly wearing funny hat yes waffle digress date backed c2 zoom front information manual reason mistrust manual also trust another piece trivia date back calendar goes end 2019 hurry want use date back three summer vacations worth date imprinting left back c2 zoom hand c2 predecessor similar looking leica af c1 used standard 40mm f2 8 lens built teleconverter double focal length 80mm f5 6 used af c1 read 40mm setting pretty good 80mm setting cameras essentially minoltas disguise af c1 redecorated minolta af tele super c2 zoom based minolta riva zoom 90c use european names minoltas throughout names japan us really need know google away cameras functionality slightly differently designed bodies fake money real dress fake money used buy waffles wide end zoom minoltas state minimum focal length 38mm leicas list 40mm taken cameras apart check suspect lenses actually identical two millimeters well within tolerances call lens 40mm even leica slightly focal length knowing history leica minolta sharing lens designs especially comes zooms seems odd leica would insisted redesign lens point shoot company used optical designs identical minolta even sigma r series lenses let talk specifically c2 zoom though first make note talking c2 zoom entirely different camera later leica c2 c2 sleek somewhat coveted c2 zoom hand appears bulbous whale like unlikable though c2 zoom one word eccentric eccentric looking eccentr ...

# %% [markdown]
# # Stemming

# %%
# # import these modules
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize

# ps = PorterStemmer()

# for w in raw_text_norm_uni_stopnltk_token:
#     print(w, " : ", ps.stem(w))

import nltk
lemma = nltk.wordnet.WordNetLemmatizer()

# for token in raw_text_norm_uni_stopnltk_token:
#     print(token, " : ", lemma.lemmatize(token))
# Out:
# 'eating'

# %%
import spacy
# from nltk.stem import PorterStemmer

clean_token = []
nlp = spacy.load("en_core_web_sm")

doc = nlp(raw_text_norm_uni_stopnltk_join)
for token in doc:
    # print(token, " : ", token.lemma_)
    clean_token.append(token)
    
clean_token
# Out:
# [point,
#  shoot,
#  leica,
#  c2,
#  zoom,
#  review,
#  mind,
#  torsten,
#  kathke,
#  september,
#  26,
#  2016,
#  dream,
#  someone,
#  give,
#  leica,
#  dream,
#  alive,
#  well,
#  least,
#  completely,
#  dead,
#  given,
#  leica,
#  c2,
#  zoom,
#  months,
#  ago,
#  friend,
#  colleague,
#  mine,
#  made,
#  intervention,
#  mother,
#  decided,
#  sifting,
#  family,
#  member,
#  collection,
#  things,
#  keep,
#  nikon,
#  slr,
#  trash,
#  lesser,
#  cameras,
#  co,
#  conspirator,
#  visual,
#  arts,
#  friend,
#  pointed,
#  might,
#  know,
#  someone,
#  could,
#  use,
#  unwanted,
#  things,
#  one,
#  monday,
#  june,
#  found,
#  two,
#  cameras,
#  several,
#  camera,
#  related,
#  odds,
#  ends,
#  desk,
#  work,
#  one,
#  cameras,
#  ridiculously,
#  well,
#  built,
#  voigtl,
#  nder,
#  rangefinder,
#  1950s,
#  plastic,
#  point,
#  shoot,
#  1990s,
#  course,
#  review,
#  plastic,
#  point,
#  shoot,
#  first,
#  mean,
#  wants,
#  hear,
#  yet,
#  quality,
#  workmanship,
#  period,
#  skimping,
#  rule,
#  camera,
#  construction,
#  build,
#  things,
#  anymore,
#  country,
#  going,
#  tubes,
#  country,
#  matter,
#  one,
#  bothers,
#  anymore,
#  precisely,
#  everything,
#  sucks,
#  attention,
#  spans,
#  instagram,
#  internet,
#  kids,
#  internet,
#  right,
#  mean,
#  right,
#  even,
#  want,
#  hear,
#  cameras,
#  trust,
#  voigtl,
#  nder,
#  easily,
#  survive,
#  another,
#  hundred,
#  years,
#  plenty,
#  time,
#  review,
#  one,
#  later,
#  plastic,
#  point,
#  shoot,
#  hand,
#  good,
#  long,
#  electronics,
#  keep,
#  working,
#  maybe,
#  hundred,
#  years,
#  maybe,
#  week,
#  half,
#  maybe,
#  surprise,
#  us,
#  become,
#  queen,
#  robots,
#  finally,
#  inevitably,
#  rise,
#  know,
#  future,
#  know,
#  today,
#  plastic,
#  love,
#  plastic,
#  embrace,
#  plastic,
#  shall,
#  worship,
#  altar,
#  made,
#  plastic,
#  bunnies,
#  bunnies,
#  must,
#  bunnies,
#  slightly,
#  soft,
#  corners,
#  chromatic,
#  aberrations,
#  visible,
#  plastic,
#  leicacontents1,
#  plastic,
#  leica2,
#  leica,
#  c22,
#  1,
#  auto,
#  zoom2,
#  2,
#  lens2,
#  3,
#  framing2,
#  4,
#  flash2,
#  5,
#  dx,
#  reading2,
#  6,
#  remote,
#  control3,
#  conclusions,
#  decision,
#  favour,
#  plastic,
#  camera,
#  helped,
#  along,
#  presence,
#  coveted,
#  little,
#  red,
#  dot,
#  five,
#  letters,
#  calligraphic,
#  white,
#  writing,
#  camera,
#  leica,
#  reached,
#  thirties,
#  faculties,
#  intact,
#  bought,
#  used,
#  dozens,
#  cameras,
#  written,
#  liked,
#  loved,
#  others,
#  leica,
#  leica,
#  guys,
#  definitive,
#  camera,
#  century,
#  camera,
#  changed,
#  everything,
#  photojournalism,
#  made,
#  plastic,
#  leica,
#  c2,
#  leica,
#  c2,
#  zoom,
#  maybe,
#  higher,
#  plane,
#  built,
#  order,
#  leica,
#  mp,
#  never,
#  meant,
#  supposed,
#  fill,
#  spot,
#  series,
#  leicas,
#  early,
#  1990s,
#  spot,
#  point,
#  occupied,
#  successful,
#  leica,
#  cl,
#  zoom,
#  range,
#  c2,
#  clue,
#  goes,
#  40,
#  mm,
#  leica,
#  cl,
#  standard,
#  lens,
#  focal,
#  length,
#  90,
#  mm,
#  focal,
#  length,
#  cl,
#  dedicated,
#  lens,
#  zoom,
#  starts,
#  acceptable,
#  f3,
#  5,
#  40,
#  mm,
#  end,
#  90,
#  mm,
#  narrow,
#  f7,
#  7,
#  remains,
#  leica,
#  also,
#  came,
#  real,
#  leather,
#  bag,
#  means,
#  still,
#  usable,
#  bag,
#  today,
#  plagued,
#  deterioration,
#  whatever,
#  cheap,
#  material,
#  used,
#  many,
#  camera,
#  bags,
#  cases,
#  70s,
#  onward,
#  fyi,
#  date,
#  back,
#  version,
#  c2,
#  zoom,
#  inclined,
#  go,
#  full,
#  90s,
#  put,
#  date,
#  image,
#  area,
#  pictures,
#  altogether,
#  bad,
#  idea,
#  usually,
#  implemented,
#  badly,
#  c2,
#  zoom,
#  always,
#  blasted,
#  date,
#  every,
#  picture,
#  smarter,
#  way,
#  would,
#  let,
#  camera,
#  put,
#  date,
#  first,
#  picture,
#  day,
#  subsequent,
#  images,
#  date,
#  actually,
#  changes,
#  want,
#  use,
#  today,
#  people,
#  used,
#  1990s,
#  prints,
#  made,
#  prints,
#  got,
#  mixed,
#  given,
#  away,
#  wanted,
#  know,
#  every,
#  print,
#  day,
#  well,
#  portrait,
#  truly,
#  wearing,
#  funny,
#  hat,
#  yes,
#  waffle,
#  digress,
#  date,
#  backed,
#  c2,
#  zoom,
#  front,
#  information,
#  manual,
#  reason,
#  mistrust,
#  manual,
#  also,
#  trust,
#  another,
#  piece,
#  trivia,
#  date,
#  back,
#  calendar,
#  goes,
#  end,
#  2019,
#  hurry,
#  want,
#  use,
#  date,
#  back,
#  three,
#  summer,
#  vacations,
#  worth,
#  date,
#  imprinting,
#  left,
#  back,
#  c2,
#  zoom,
#  hand,
#  c2,
#  predecessor,
#  similar,
#  looking,
#  leica,
#  af,
#  c1,
#  used,
#  standard,
#  40,
#  mm,
#  f2,
#  8,
#  lens,
#  built,
#  teleconverter,
#  double,
#  focal,
#  length,
#  80,
#  mm,
#  f5,
#  6,
#  used,
#  af,
#  c1,
#  read,
#  40,
#  mm,
#  setting,
#  pretty,
#  good,
#  80,
#  mm,
#  setting,
#  cameras,
#  essentially,
#  minoltas,
#  disguise,
#  af,
#  c1,
#  redecorated,
#  minolta,
#  af,
#  tele,
#  super,
#  c2,
#  zoom,
#  based,
#  minolta,
#  riva,
#  zoom,
#  90c,
#  use,
#  european,
#  names,
#  minoltas,
#  throughout,
#  names,
#  japan,
#  us,
#  really,
#  need,
#  know,
#  google,
#  away,
#  cameras,
#  functionality,
#  slightly,
#  differently,
#  designed,
#  bodies,
#  fake,
#  money,
#  real,
#  dress,
#  fake,
#  money,
#  used,
#  buy,
#  waffles,
#  wide,
#  end,
#  zoom,
#  minoltas,
#  state,
#  minimum,
#  focal,
#  length,
#  38,
#  mm,
#  leicas,
#  list,
#  40,
#  mm,
#  taken,
#  cameras,
#  apart,
#  check,
#  suspect,
#  lenses,
#  actually,
#  identical,
#  two,
#  millimeters,
#  well,
#  within,
#  tolerances,
#  call,
#  lens,
#  40,
#  mm,
#  even,
#  leica,
#  slightly,
#  focal,
#  length,
#  knowing,
#  history,
#  leica,
#  minolta,
#  sharing,
#  lens,
#  designs,
#  especially,
#  comes,
#  zooms,
#  seems,
#  odd,
#  leica,
#  would,
#  insisted,
#  redesign,
#  lens,
#  point,
#  shoot,
#  company,
#  used,
#  optical,
#  designs,
#  identical,
#  minolta,
#  even,
#  sigma,
#  r,
#  series,
#  lenses,
#  let,
#  talk,
#  specifically,
#  c2,
#  zoom,
#  though,
#  first,
#  make,
#  note,
#  talking,
#  c2,
#  zoom,
#  entirely,
#  different,
#  camera,
#  later,
#  leica,
#  c2,
#  c2,
#  sleek,
#  somewhat,
#  coveted,
#  c2,
#  zoom,
#  hand,
#  appears,
#  bulbous,
#  whale,
#  like,
#  unlikable,
#  though,
#  c2,
#  zoom,
#  one,
#  word,
#  eccentric,
#  eccentric,
#  looking,
#  eccentric,
#  operation,
#  operate,
#  find,
#  battery,
#  camera,
#  takes,
#  relatively,
#  common,
#  2cr5,
#  lithium,
#  battery,
#  found,
#  also,
#  example,
#  many,
#  minolta,
#  dynax,
#  maxxum,
#  alpha,
#  slr,
#  cameras,
#  even,
#  get,
#  third,
#  party,
#  chargers,
#  rechargeables,
#  c2,
#  zoom,
#  work,
#  uncomplainingly,
#  auto,
#  zoom,
#  switch,
#  c2,
#  zoom,
#  lift,
#  camera,
#  eye,
#  point,
#  somewhere,
#  point,
#  person,
#  notice,
#  immediately,
#  leica,
#  tries,
#  helpful,
#  automatically,
#  zooms,
#  face,
#  crops,
#  image,
#  supposedly,
#  pleasing,
#  frame,
#  going,
#  equivocate,
#  inane,
#  one,
#  thing,
#  minolta,
#  makers,
#  first,
#  popular,
#  autofocus,
#  slr,
#  calculator,
#  amongst,
#  cameras,
#  minolta,
#  7000,
#  think,
#  take,
#  auto,
#  everything,
#  one,
#  step,
#  save,
#  trouble,
#  actually,
#  framing,
#  photo,
#  want,
#  take,
#  half,
#  understand,
#  coming,
#  mean,
#  one,
#  relative,
#  friend,
#  take,
#  picture,
#  save,
#  life,
#  think,
#  cut,
#  heads,
#  think,
#  waaaay,
#  much,
#  sky,
#  background,
#  think,
#  every,
#  bad,
#  photo,
#  clich,
#  ever,
#  hint,
#  know,
#  person,
#  probably,
#  case,
#  auto,
#  zoom,
#  away,
#  auto,
#  zoomed,
#  cityscape,
#  super,
#  sharp,
#  however,
#  confounding,
#  think,
#  point,
#  presume,
#  must,
#  late,
#  1980s,
#  early,
#  1990s,
#  leica,
#  executives,
#  traveled,
#  osaka,
#  checked,
#  cameras,
#  minolta,
#  manufacturing,
#  masses,
#  picked,
#  riva,
#  zoom,
#  90c,
#  said,
#  yup,
#  one,
#  leica,
#  love,
#  cap,
#  n,
#  crunch,
#  trying,
#  slot,
#  something,
#  series,
#  people,
#  can,
#  not,
#  afford,
#  still,
#  would,
#  like,
#  leica,
#  make,
#  regret,
#  buying,
#  one,
#  overpriced,
#  compacts,
#  immediately,
#  alright,
#  calming,
#  auto,
#  zoom,
#  work,
#  well,
#  thank,
#  auto,
#  selects,
#  frame,
#  focus,
#  anything,
#  75,
#  cm,
#  8,
#  m,
#  away,
#  focus,
#  farther,
#  away,
#  would,
#  panoramic,
#  shot,
#  auto,
#  zoom,
#  incredibly,
#  unhelpfully,
#  decides,
#  focus,
#  lens,
#  90,
#  mm,
#  see,
#  may,
#  want,
#  learn,
#  routine,
#  switch,
#  c2,
#  zoom,
#  switch,
#  auto,
#  zoom,
#  one,
#  fell,
#  swoop,
#  ah,
#  good,
#  news,
#  insanity,
#  fact,
#  turned,
#  long,
#  pressing,
#  self,
#  timer,
#  button,
#  moving,
#  zoom,
#  lever,
#  bit,
#  bad,
#  news,
#  stay,
#  camera,
#  turns,
#  happens,
#  3,
#  minutes,
#  order,
#  preserve,
#  battery,
#  downer,
#  auto,
#  zoom,
#  setting,
#  also,
#  might,
#  want,
#  street,
#  photography,
#  capture,
#  pictures,
#  family,
#  gathering,
#  without,
#  turn,
#  camera,
#  might,
#  take,
#  extra,
#  second,
#  make,
#  miss,
#  moment,
#  unfortunately,
#  par,
#  course,
#  90s,
#  cameras,
#  turn,
#  c2,
#  zoom,
#  back,
#  hello,
#  auto,
#  zoom,
#  second,
#  bad,
#  design,
#  decision,
#  made,
#  c2,
#  zoom,
#  technical,
#  reason,
#  camera,
#  remember,
#  state,
#  auto,
#  zoom,
#  setting,
#  remembers,
#  whether,
#  want,
#  pre,
#  flash,
#  uses,
#  set,
#  sadly,
#  also,
#  smart,
#  enough,
#  remember,
#  purposely,
#  set,
#  flash,
#  completely,
#  understand,
#  camera,
#  designers,
#  wanted,
#  make,
#  idiot,
#  proof,
#  remember,
#  settings,
#  others,
#  switched,
#  makes,
#  user,
#  experience,
#  inconsistent,
#  confusing,
#  less,
#  must,
#  put,
#  function,
#  every,
#  even,
#  somewhat,
#  advanced,
#  photographer,
#  want,
#  turn,
#  right,
#  away,
#  let,
#  turn,
#  let,
#  stay,
#  ok,
#  probably,
#  working,
#  anymore,
#  leica,
#  minolta,
#  mean,
#  minolta,
#  even,
#  make,
#  cameras,
#  anymore,
#  probably,
#  retired,
#  potent,
#  decision,
#  makers,
#  camera,
#  world,
#  surely,
#  sitting,
#  home,
#  money,
#  gold,
#  plated,
#  ...]

# %% [markdown]
# # Full Function
# #### Normalize + Unicode Removed + Stopword Removed(NLTK) + Stemming(SPACY) + Tokenized

# %%
import re
import nltk.corpus as nltkc
import spacy
# ------------------------------------------------
# ------------------------------------------------
def txt_cleaner(raw_text):
    raw_text_norm = raw_text.lower()
    raw_text_norm_uni = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", " ", raw_text_norm)
    # ------------------------------------------------
    stopwords = set(nltkc.stopwords.words('english'))
    raw_text_norm_uni_stopnltk_token = []
    for word in raw_text_norm_uni.split():
        if word not in stopwords:
            raw_text_norm_uni_stopnltk_token.append(word)
    raw_text_norm_uni_stopnltk_join = " ".join(raw_text_norm_uni_stopnltk_token)
    # ------------------------------------------------
    clean_token = []
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(raw_text_norm_uni_stopnltk_join)
    for token in doc:
        # print(token, " : ", token.lemma_)
        clean_token.append(token)
    return clean_token

# %% [markdown]
# # finalfunction : raw text cleaning

# %%
import re
import spacy
from nltk.corpus import stopwords

def txt_cleaner(raw_text):
    """Normalize + Unicode Removed + Stopword Removed(NLTK) + Stemming(SPACY) + Tokenized"""
    
    # Normalize and remove special characters
    raw_text = re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", " ", raw_text.lower())
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in raw_text.split() if word not in stop_words]
    raw_text = " ".join(words)
    
    # Perform lemmatization
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(raw_text)
    clean_tokens = [token.lemma_ for token in doc]
    
    return clean_tokens

# %% [markdown]
# # Final Function in OOP Class form

# %%
import re
import spacy
from nltk.corpus import stopwords

class TextCleaner:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")
        self.stop_words = set(stopwords.words('english'))

    def normalize(self, raw_text):
        """Remove special characters and lowercase text"""
        return re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", " ", raw_text.lower())

    def remove_stopwords(self, raw_text):
        """Remove stopwords"""
        words = [word for word in raw_text.split() if word not in self.stop_words]
        return " ".join(words)

    def lemmatize(self, raw_text):
        """Perform lemmatization"""
        doc = self.nlp(raw_text)
        return [token.lemma_ for token in doc]

    def clean(self, raw_text):
        """Clean text by normalizing, removing stopwords, and lemmatizing"""
        raw_text = self.normalize(raw_text)
        raw_text = self.remove_stopwords(raw_text)
        return self.lemmatize(raw_text)

# %%
text_cleaner = TextCleaner()
normalized_text = text_cleaner.normalize(raw_text)
no_stopwords_text = text_cleaner.remove_stopwords(normalized_text)
lemmatized_text = text_cleaner.lemmatize(no_stopwords_text)

# %% [markdown]
# # Unit testing

# %%
import unittest

class TestTextCleaner(unittest.TestCase):
    def setUp(self):
        self.text_cleaner = TextCleaner()
        self.raw_text = "This is some raw text that needs to be cleaned."
        self.normalized_text = "this is some raw text that needs to be cleaned "
        self.normalized_text_false = "this is some raw text that needs to be cleaned"
        self.no_stopwords_text = "This raw text needs cleaned."
        self.no_stopwords_text_false = "This raw text needs cleaned"
        self.lemmatized_text = ['raw', 'text', 'need', 'clean']

    def test_normalize(self):
        self.assertEqual(self.text_cleaner.normalize(self.raw_text), self.normalized_text)
        self.assertNotEqual(self.text_cleaner.normalize(self.raw_text), self.normalized_text_false)

    def test_remove_stopwords(self):
        self.assertEqual(self.text_cleaner.remove_stopwords(self.raw_text), self.no_stopwords_text)
        self.assertNotEqual(self.text_cleaner.remove_stopwords(self.raw_text), self.raw_text)

#     Cannot test due to depends on each library's algorithm
#     def test_lemmatize(self):
#         self.assertEqual(self.text_cleaner.lemmatize(self.no_stopwords_text), self.lemmatized_text)
        
    def test_clean(self):
        self.assertEqual(self.text_cleaner.clean(self.raw_text), self.lemmatized_text)
        self.assertNotEqual(self.text_cleaner.clean(self.raw_text), self.raw_text)

# if __name__ == '__main__':
#     unittest.main()
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_clean (__main__.TestTextCleaner) ... ok
# test_normalize (__main__.TestTextCleaner) ... ok
# test_remove_stopwords (__main__.TestTextCleaner) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 1.809s
#
# OK

# %%
text_cleaner = TextCleaner()
normalized_text = text_cleaner.clean('This is some raw text that needs to be cleaned.')
normalized_text
# Out:
# ['raw', 'text', 'need', 'clean']

# %% [markdown]
# # Run Time

# %%
import time

start = time.time()

text_cleaner = TextCleaner()
text_cleaner.clean(raw_text)

end = time.time()

print("Time : ", end-start, " sec.")
# Out:
# Time :  1.1791625022888184  sec.

# %% [markdown]
# # prep. for invert index counting frequency
# ### kept as dictionary

# %%
# clean_text = ['first', 'word', 'second', 'text', 'hello', 'third']
clean_text = lemmatized_text

freq_dict = {}
for gram in clean_text:
    if gram in freq_dict:
        freq_dict[gram] += 1
    else:
        freq_dict[gram] = 1

# %%
from collections import Counter

freq_dict_function = Counter(lemmatized_text)

print("Total Words : ", len(freq_dict_function))
for i in freq_dict_function:
    if freq_dict_function[i] > 10:
        print(i, " : ", freq_dict_function[i])
# Out:
# Total Words :  1056
# point  :  23
# shoot  :  21
# leica  :  60
# c2  :  46
# zoom  :  72
# well  :  18
# make  :  17
# camera  :  55
# know  :  12
# could  :  11
# use  :  23
# one  :  21
# end  :  23
# plastic  :  17
# even  :  11
# want  :  27
# good  :  11
# long  :  12
# maybe  :  11
# auto  :  21
# like  :  13
# 40  :  15
# mm  :  32
# lens  :  20
# 90  :  17
# also  :  15
# still  :  13
# image  :  13
# picture  :  21
# would  :  20
# set  :  14
# minolta  :  19
# wide  :  17
# take  :  17
# much  :  11
# flash  :  11
# film  :  21
